# %% [markdown]
# - 모델링에 가장 적합한 확률분포는 정규분포이나 실제로 많은 변수가 특정방향으로 치우쳐 있음
# - 한쪽으로 치우친 변수에서 치우친 반대 방향의 값(꼬리부분)들이 이상치처럼 작용할 수 있으므로, 이러한 치우침을 제거해야 함

# %% [markdown]
# ### 탐색방법 : 왜도(skewness)
#
# - 변수 치우침을 확인하기 가장 적절한 척도로는 왜도가 있음
# - 왜도
#     - 분포의 비대칭도를 나타내는 통계량
#     ![image.png](attachment:image.png)
#
#     - 왜도의 절대값이 <b> 1.5이상 </b> 이면 치우쳤다고 판단

# %%
import pandas as pd
import numpy as np

# %%
# 데이터 경로 설정 및 데이터 불러오기 / 헤더가 없는 데이터
import pandas as pd
df = pd.read_csv("./데이터/sonar.csv",header=None)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %% [markdown]
# - 컬럼명이 없어서 숫자 인덱스로 설정
# - 컬럼명을 재설정 : 60번 컬럼 -> 결정변수(컬럼명 Y로 설정)
#     - 0~59번 컬럼은 번호 앞에 'band' 부착

# %%
columns=['band'+str(i) for i in range(1,61)]
columns.append('Y')

# %%
df.columns=columns
df.head()
# Out:
#     band1   band2   band3   band4   band5   band6   band7   band8   band9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#    band10  ...  band52  band53  band54  band55  band56  band57  band58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#    band59  band60  Y
# 0  0.0090  0.0032  R
# 1  0.0052  0.0044  R
# 2  0.0095  0.0078  R
# ...

# %%
X=df.drop('Y',axis=1)
Y=df['Y']

# %%
# 학습 데이터와 평가 데이터로 분리
from sklearn.model_selection import train_test_split
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, random_state=4)

# %%
# 학습데이터로 왜도 확인 -> band4의 왜도가 큼(그래프로 확인-hist())
Train_X.skew()
# Out:
# band1     2.122757
# band2     2.206600
# band3     2.980038
# band4     3.765729
# band5     2.316077
# band6     1.319739
# band7     0.995473
# band8     1.391214
# band9     1.659002
# band10    1.421497
# band11    1.115515
# band12    0.647377
# band13    0.753832
# band14    1.131916
# band15    0.887139
# band16    0.671871
# band17    0.677022
# band18    0.636263
# band19    0.366953
# band20    0.012580
# band21   -0.160018
# band22   -0.421629
# band23   -0.613929
# band24   -0.651260
# band25   -0.753808
# band26   -0.604019
# band27   -0.634036
# band28   -0.684365
# band29   -0.539911
# band30   -0.188124
# band31    0.208961
# band32    0.252053
# band33    0.360365
# band34    0.509935
# band35    0.543931
# band36    0.581213
# band37    0.660349
# band38    0.929952
# band39    0.897142
# band40    0.909556
# band41    0.874074
# band42    0.866778
# band43    0.921569
# band44    1.295647
# band45    1.274154
# band46    1.611226
# band47    1.794758
# ...

# %%
# %matplotlib inline
df.band4.hist()
# Out:
# <AxesSubplot:>

# %%
# 왜도의 절대값이 1.5이상인 컬럼명을 확인

# %%
import numpy as np
b_var=Train_X.columns[Train_X.skew().abs()>1.5]

# %%
np.log10(Train_X[b_var])
# Out:
# C:\Users\JungHun.DESKTOP-JRGUSS9\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)
#         band1     band2     band3     band4     band5     band9    band46  \
# 82  -1.388277 -1.375718 -1.241845 -1.886057 -1.737549 -0.637895 -0.563519
# 204 -1.490797 -1.995679 -1.525784 -1.248721 -1.119186 -0.987163 -2.096910
# 12  -2.102373 -2.065502 -2.259637 -1.602060 -1.463442 -0.996109 -1.178486
# 142 -1.279014 -1.249492 -0.913996 -0.918653 -1.609065 -0.639975 -0.290476
# 116 -2.026872 -1.477556 -1.514279 -1.424812 -0.887395 -0.728158 -0.959793
# ..        ...       ...       ...       ...       ...       ...       ...
# 129 -0.862963 -0.911510 -0.858550 -0.828566 -0.750557 -0.787812 -0.973875
# 197 -1.436519 -1.375718 -1.297569 -1.602060 -1.224754 -0.848018 -0.702239
# 183 -2.017729 -1.393619 -1.166216 -1.162412 -1.052076 -0.594142 -0.654430
# ...

# %%
np.log10(Train_X[b_var]).band4.hist()
# Out:
# C:\Users\JungHun.DESKTOP-JRGUSS9\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)
# <AxesSubplot:>

# %%
# 학습데이터에서 왜도가 심한 컬럼들만 로그변환 후 대입
Train_X[b_var]=np.log10(Train_X[b_var])

# %%
Train_X.columns[Train_X.skew().abs()>1.5] # 모든 컬럼은 왜도가 1.5 이하
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### 로그변환을 하다보면 변환값이 inf로 변환 될 수 있음
# - 이렇게 변환된 경우는 이상치로 처리해서 해당 레코드를 제거하는 것을 고려

# %%
# 테스트 데이터도 동일하게 처리
Test_X[b_var] = np.log10(Test_X[b_var])

# %%
Test_X.head()
# Out:
#         band1     band2     band3     band4     band5   band6   band7   band8  \
# 33  -1.354578 -1.321482 -2.309804 -1.235824 -1.555955  0.0678  0.1664  0.1490
# 176 -1.197226 -1.149354 -1.343902 -1.477556 -1.732828  0.1260  0.1015  0.1918
# 105 -1.935542 -1.747147 -1.347754 -0.960189 -0.718285  0.0924  0.0761  0.1092
# 18  -1.568636 -2.036212 -1.838632 -1.555955 -1.385103  0.0757  0.1026  0.1138
# 90  -1.899629 -1.284833 -1.206908 -1.285670 -0.969805  0.2587  0.2304  0.2067
#
#         band9  band10  ...    band51    band52  band53  band54    band55  \
# 33  -1.011441  0.1268  ... -1.677781 -1.690370  0.0216  0.0135 -2.259637
# 176 -0.473402  0.3900  ... -1.812479 -2.318759  0.0025  0.0087 -2.142668
# 105 -1.120904  0.1006  ... -2.508638 -1.787812  0.0099  0.0084 -1.568636
# 18  -1.100179  0.1520  ... -2.346787 -2.075721  0.0010  0.0018 -2.167491
# 90  -0.466482  0.4284  ... -2.568636 -1.681937  0.0048  0.0199 -1.899629
#
#        band56    band57    band58    band59    band60
# ...

# %%
Test_X.columns[Train_X.skew().abs()>1.5]
# Out:
# Index([], dtype='object')

# %% [markdown]
# #### 치우침 제거
# - 왜도가 1.5 이상인 변수들에 대해서 log 변환을 진행
#     - log 변환 후에 왜도를 다시 확인해서 치우침이 제거되었는 지 봐야함
