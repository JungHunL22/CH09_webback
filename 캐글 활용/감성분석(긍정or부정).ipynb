# %% [markdown]
# # 캐글 데이터 활용 NLP 분석

# %%
import pandas as pd

# %%
amazon=pd.read_csv('data/Reviews.csv')

# %%
amazon.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# ## 감성 분석

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sa=SentimentIntensityAnalyzer()
emo=sa.polarity_scores(exam)
print(exam)
print(emo)
# 리뷰 내용은 강아지 음식의 질이 좋다는 긍정적인 내용
# neg,neu,pos는 차례대로 부정/중립/긍정 지수
# compound 지수는 음수일수록 부정,양수일수록 긍정(-1~1사이)
# 0.94이므로 긍정일 가능성이 매우 커보임
# Out:
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441}

# %%
def emotion_check(text):
    res=[sa.polarity_scores(sentence) for sentence in text]
    return res

# %%
res=emotion_check(review)

# %%
emotions=pd.DataFrame(res)

# %%
emotions.compound
# Out:
# 0         0.9441
# 1        -0.5664
# 2         0.8265
# 3         0.0000
# 4         0.9468
#            ...
# 568449    0.8589
# 568450   -0.4848
# 568451    0.4352
# 568452    0.9717
# 568453    0.4754
# Name: compound, Length: 568454, dtype: float64

# %%
NP=['Negative'  if score<0 else 'Positive' for score in emotions['compound']]

# %%
NP
# Out:
# ['Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
# ...

# %%
amazon['NP']=NP

# %%
amazon
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
import seaborn as sns

# %% [markdown]
# 1점에 가까울수록 부정적 리뷰가 많고, 5점에 가까울수록 긍정적 리뷰가 많음.

# %%
sns.countplot(x=amazon['Score'],hue=amazon['NP'],dodge=False)
# Out:
# <AxesSubplot:xlabel='Score', ylabel='count'>
